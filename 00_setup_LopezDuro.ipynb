# %%
# P17: Imprimir fecha y versión para trazabilidad
# !python --version
import datetime
print(f"Fecha de ejecución: {datetime.datetime.now().isoformat()}")
# Out:
# Python 3.12.12
# Fecha de ejecución: 2025-12-26T11:19:08.067370

# %% [markdown]
# ## DATOS
# Se cargará el dataset (ej. MNIST) y se normalizarán los valores.
#
# ## MÉTODO
# Se define una arquitectura MLP densa (ej. 784-128-10) con activación ReLU.
#
# ## MÉTRICAS
# Se utilizará Cross-Entropy Loss y Accuracy para evaluar el desempeño.
#
# ## DISCUSIÓN
# Se analizarán las curvas de aprendizaje para detectar sobreajuste.

# %%
# P19: Generar Hash SHA-256
import hashlib

# Simulamos el contenido del archivo actual para el ejercicio
contenido = b"Contenido del notebook 00_setup_LopezDuro"
sha256_hash = hashlib.sha256(contenido).hexdigest()

print(f"SHA-256 calculado: {sha256_hash}")
# Out:
# SHA-256 calculado: 35486c6361cbe67fcd126664f9a461872c45dc7caa55a4b5518e89d45a8dd3aa

# %%
# P20: Crear registro WORM
import json

registro = {
    "archivo": "00_setup_LopezDuro.ipynb",
    "sha256": sha256_hash,
    "fecha": datetime.datetime.now().isoformat(),
    "autor": "Sergio Lopez Duro"
}

nombre_json = "registro_hash.json"
with open(nombre_json, "w") as f:
    json.dump(registro, f, indent=4)

print(f"Archivo '{nombre_json}' generado. Contenido:")
print(json.dumps(registro, indent=4))
# Out:
# Archivo 'registro_hash.json' generado. Contenido:
# {
#     "archivo": "00_setup_LopezDuro.ipynb",
#     "sha256": "35486c6361cbe67fcd126664f9a461872c45dc7caa55a4b5518e89d45a8dd3aa",
#     "fecha": "2025-12-26T11:19:13.212819",
#     "autor": "Sergio Lopez Duro"
# }
